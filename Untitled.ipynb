# %%
# !utils_qcri/clustering.sh 1000 0 "visualize" "activations_cpp_cuda"
# Out:
# Preparing for visualize
# Iteration 1, Centroid shift: 28.650965
# Iteration 2, Centroid shift: 38.536182
# Iteration 3, Centroid shift: 25.308615
# Iteration 4, Centroid shift: 24.689344
# Iteration 5, Centroid shift: 18.587671
# Iteration 6, Centroid shift: 16.779099
# Iteration 7, Centroid shift: 14.909066
# Iteration 8, Centroid shift: 9.200484
# Iteration 9, Centroid shift: 12.088678
# Iteration 10, Centroid shift: 5.230927
# Iteration 11, Centroid shift: 4.931685
# Iteration 12, Centroid shift: 2.273660
# Iteration 13, Centroid shift: 5.171349
# Iteration 14, Centroid shift: 4.461759
# Iteration 15, Centroid shift: 0.862345
# Iteration 16, Centroid shift: 0.000000
# Convergence reached.
# Clustering completed in 2.11 seconds.
# Results saved to visualize_1000/layer0/encoder-clusters-kmeans-1000.txt
# Iteration 1, Centroid shift: 31.388723
# Iteration 2, Centroid shift: 30.696302
# Iteration 3, Centroid shift: 25.305534
# Iteration 4, Centroid shift: 23.809771
# ...

# %%
# !rm activations_cpp_cuda/ -r

# %%
# !utils_qcri/get_alignment.sh 1000 12
# Out:
# {('(', '('), ('=', '='), (',', ','), ('*', '*')}
# Source Cluster 5 Target Cluster 30
# Source Cluster Size 4 Target Cluster Size 9
# 4 4
# {('double', 'double'), (',', ','), ('b', 'b'), ('float', 'float'), ('int', 'int'), ('*', '*')}
# Source Cluster 50 Target Cluster 641
# Source Cluster Size 6 Target Cluster Size 12
# 6 6
# {('void', 'void'), ('float', 'float')}
# Source Cluster 72 Target Cluster 522
# Source Cluster Size 2 Target Cluster Size 4
# 2 2
# {('void', 'void'), ('float', 'float')}
# Source Cluster 72 Target Cluster 531
# Source Cluster Size 2 Target Cluster Size 3
# 2 2
# {('void', 'void'), ('float', 'float')}
# Source Cluster 72 Target Cluster 564
# Source Cluster Size 2 Target Cluster Size 3
# 2 2
# {('(', '('), ('int', 'int'), ('*', '*')}
# Source Cluster 121 Target Cluster 150
# Source Cluster Size 3 Target Cluster Size 7
# 3 3
# {('(', '('), ('int', 'int'), ('*', '*')}
# Source Cluster 121 Target Cluster 197
# Source Cluster Size 3 Target Cluster Size 7
# 3 3
# ...

# %%
import os
os.environ['HF_HOME'] = '/work/instruction/coms-599-29-f24/group_4_clustering/Cross-Lingual-Code-Concept-Analysis/cache/'
from huggingface_hub import login
login(token = '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')

# %%
from transformers import AutoTokenizer, EncoderDecoderModel

# Load the CodeRosetta model and tokenizer
model = EncoderDecoderModel.from_pretrained('CodeRosetta/CodeRosetta_cpp2cuda_ft')
tokenizer = AutoTokenizer.from_pretrained('CodeRosetta/CodeRosetta_cpp2cuda_ft')

# %%
# !sbatch slurm_job.sh
# Out:
# Submitted batch job 2168882

# %%
# !squeue --me
# Out:
#              JOBID PARTITION     NAME     USER ST       TIME  NODES NODELIST(REASON)
#            2168880       gpu interact xiaoquan  R      10:15      1 amp-6

# %%
# !utils_qcri/activation_extraction_without_filtering.sh 0
# Out:
# [INFO] encoder filtered file is saved as: activationsOutput_no_filtering_0//input.in.tok.sent_len
# [INFO] decoder filtered file is saved as: activationsOutput_no_filtering_0//label.out.tok.sent_len
# [INFO] Number of skipped lines: 0
# Reading file:  activationsOutput_no_filtering_0//input.in.tok.sent_len
# Saving output file
# ######### Singletons #############
# ...
